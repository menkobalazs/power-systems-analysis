# %% [markdown]
# # Installation
# - PIXI: [https://pixi.prefix.dev/latest/installation/](https://pixi.prefix.dev/latest/installation/)
# - PyPSA-EUR: [https://pypsa-eur.readthedocs.io/en/latest/installation.html](https://pypsa-eur.readthedocs.io/en/latest/installation.html)
