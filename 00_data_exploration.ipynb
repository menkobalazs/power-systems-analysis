# %% [markdown]
# #  Hungarian dataset - Data Exploration

# %%
# packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils import data_path, week_numbers, change_costs

# %% [markdown]
# ---

# %% [markdown]
# # Potentials
# - Generators
# - Storages

# %%
potentials_generator = pd.read_excel(data_path, sheet_name='potentials_generator', index_col=0, na_values='None')
technologies_generator = potentials_generator.keys().to_numpy()
potentials_generator
# Out:
#             Solar  Wind Offshore  Wind Onshore  Hydro Run-of-river  \
# p_nom      4000.0            0.0        1500.0                30.0
# p_nom_max  6000.0            0.0        2000.0                36.0
# p_nom_min     0.0            0.0           0.0                 0.0
# up            NaN            NaN           NaN                 NaN
# down          NaN            NaN           NaN                 NaN
# ramp_up       1.0            1.0           1.0                 1.0
# ramp_down     1.0            1.0           1.0                 1.0
#
#            Hydro Water Reservoir  Geothermal  Biomass   Waste  Fossil Lignite  \
# p_nom                       25.0         0.0   500.00  300.00          600.00
# p_nom_max                   28.0         0.0   600.00  300.00          600.00
# p_nom_min                    0.0         0.0     0.00    0.00            0.00
# up                           NaN         NaN     0.00    0.00            0.00
# down                         NaN         NaN     0.00    0.00            0.00
# ramp_up                      1.0         1.0     0.01    0.01            0.01
# ramp_down                    1.0         1.0     0.01    0.01            0.01
#
#            Fossil Hard coal  Fossil Gas   Nuclear    Fusion
# p_nom                  0.00     1900.00  2000.000   100.000
# p_nom_max              0.00     2500.00  4000.000  1000.000
# p_nom_min              0.00        0.00     0.000     0.000
# up                     0.00        0.00     0.000     0.000
# down                   0.00        0.00     0.000     0.000
# ramp_up                0.01        0.01     0.005     0.005
# ramp_down              0.01        0.01     0.005     0.005

# %%
potentials_storage = pd.read_excel(data_path, sheet_name='potentials_storage', index_col=0, na_values='None')
technologies_storage = potentials_storage.keys().to_numpy()
potentials_storage
# Out:
#            Pumped Storage Actual  Storage Actual
# p_nom_max                   2500                0
# up                             0                0
# down                           0                0

# %% [markdown]
# # Cost
# - `c1`: Capital cost [€/MW/28day] (once per power plant)
# - `c2`: Operation cost [€/MWh]
# - `c3`: Environment and CO$_2$ [€/MWh]
# - `c4`: Risk [€/MWh]
# - `c5`: Reliability [€/MWh]

# %%
costs_generator = pd.read_excel(data_path, sheet_name='costs_generator', index_col=0,na_values='None').to_dict()
pd.DataFrame(costs_generator)
# Out:
#                    Solar  Wind Offshore  Wind Onshore  Hydro Run-of-river  \
# capital      2958.861261    7832.279809   4525.317223         7582.746532
# operation       0.695652       1.565217      1.304348            0.834783
# environment     0.029459       0.023190      0.023190            0.023513
# risk            0.000268       0.006699      0.006699            0.022098
# reliability     0.159462       0.124622      0.138469            0.092852
# start_up             NaN            NaN           NaN                 NaN
# shut_down            NaN            NaN           NaN                 NaN
#
#              Hydro Water Reservoir    Geothermal      Biomass        Waste  \
# capital               10110.328710  13053.799682  7796.409521  8425.273925
# operation                 0.834783      1.739130    30.703288     0.000000
# environment               0.023513      0.021519     0.049154     0.065035
# risk                      0.022098      0.011256     0.010130     0.009005
# reliability               0.030197      0.049930     0.057433     0.057433
# start_up                       NaN           NaN     0.000100     0.000100
# shut_down                      NaN           NaN     0.000100     0.000100
#
#              Fossil Lignite  Fossil Hard coal   Fossil Gas       Nuclear  \
# capital         7796.409521       7796.409521  5221.519873  13568.077146
# operation         26.086957         26.086957    50.869565      7.826087
# environment        0.194088          0.193973     0.165463      0.051582
# risk               0.023325          0.068480     0.097517      0.112540
# reliability        0.057433          0.057433     0.015745      0.078866
# start_up                NaN               NaN          NaN           NaN
# shut_down               NaN               NaN          NaN           NaN
#
#                    Fusion
# capital      17136.154293
# operation        7.043478
# environment      0.022863
# risk             0.021104
# reliability      0.049930
# start_up              NaN
# shut_down             NaN

# %%
costs_storage = pd.read_excel(data_path, sheet_name='costs_storage', index_col=0, na_values='None').to_dict()
pd.DataFrame(costs_storage)
# Out:
#              Pumped Storage Actual  Storage Actual
# capital                3072.017467      7796.262038
# operation                 0.000000         0.000000
# environment               0.000000         0.000000
# risk                      0.000000         0.000000
# reliability               0.000000         0.000000
# start_up                  0.000100              NaN
# shut_down                 0.000100              NaN

# %%
costs_generator = pd.read_excel(data_path, sheet_name='costs_generator', index_col=0,na_values='None').to_dict()
change_costs(costs_generator, cost_params=['operation'], allow_rand_seed=False,
             function='constant', x=10)
costs_generator
# Out:
# {'Solar': {'capital': 2958.8612611764624,
#   'operation': 6.9565217391304355,
#   'environment': 0.0294591143,
#   'risk': 0.000267754,
#   'reliability': 0.159462382,
#   'start_up': nan,
#   'shut_down': nan},
#  'Wind Offshore': {'capital': 7832.279808996518,
#   'operation': 15.652173913043478,
#   'environment': 0.023189615,
#   'risk': 0.006699475,
#   'reliability': 0.124622362,
#   'start_up': nan,
#   'shut_down': nan},
#  'Wind Onshore': {'capital': 4525.317222975766,
#   'operation': 13.043478260869566,
#   'environment': 0.023189615,
#   'risk': 0.006699475,
#   'reliability': 0.138469291,
#   'start_up': nan,
#   'shut_down': nan},
#  'Hydro Run-of-river': {'capital': 7582.746532200676,
#   'operation': 8.347826086956523,
#   'environment': 0.023512888000000003,
#   'risk': 0.022098427,
#   'reliability': 0.092851873,
#   'start_up': nan,
#   'shut_down': nan},
#  'Hydro Water Reservoir': {'capital': 10110.3287096009,
#   'operation': 8.347826086956523,
#   'environment': 0.023512888000000003,
#   'risk': 0.022098427,
#   'reliability': 0.0301966625,
#   'start_up': nan,
#   'shut_down': nan},
#  'Geothermal': {'capital': 13053.799681660865,
#   'operation': 17.39130434782609,
#   'environment': 0.0215193488,
#   'risk': 0.0112557072,
#   'reliability': 0.049929513,
#   'start_up': nan,
#   'shut_down': nan},
#  'Biomass': {'capital': 7796.409520539807,
#   'operation': 307.03287988862036,
#   'environment': 0.049154009,
#   'risk': 0.01013013648,
#   'reliability': 0.057432747,
#   'start_up': 0.0001,
#   'shut_down': 0.0001},
#  'Waste': {'capital': 8425.273924667417,
#   'operation': 0.0,
#   'environment': 0.0650348508,
#   'risk': 0.00900456576,
#   'reliability': 0.057432747,
#   'start_up': 0.0001,
#   'shut_down': 0.0001},
#  'Fossil Lignite': {'capital': 7796.409520539807,
#   'operation': 260.8695652173913,
#   'environment': 0.19408830999999999,
#   'risk': 0.023324717800000002,
#   'reliability': 0.057432747,
#   'start_up': nan,
#   'shut_down': nan},
#  'Fossil Hard coal': {'capital': 7796.409520539807,
#   'operation': 260.8695652173913,
#   'environment': 0.193973105,
#   'risk': 0.0684800575,
#   'reliability': 0.057432747,
#   'start_up': nan,
#   'shut_down': nan},
#  'Fossil Gas': {'capital': 5221.519872664346,
#   'operation': 508.69565217391306,
#   'environment': 0.16546325580000001,
#   'risk': 0.09751667920000001,
#   'reliability': 0.015744818,
#   'start_up': nan,
#   'shut_down': nan},
#  'Nuclear': {'capital': 13568.077146320911,
#   'operation': 78.2608695652174,
#   'environment': 0.051581972000000004,
#   'risk': 0.1125398625,
#   'reliability': 0.078865935,
#   'start_up': nan,
#   'shut_down': nan},
#  'Fusion': {'capital': 17136.1542926418,
#   'operation': 70.43478260869566,
#   'environment': 0.022862819,
#   'risk': 0.021104451,
#   'reliability': 0.049929513,
#   'start_up': nan,
#   'shut_down': nan}}

# %% [markdown]
# # Wind and PV profiles
#
# - week **15**: middle of **April**
# - week **28**: beginning of **July**
# - week **40**: end of September / beginning of **October**
# - week **49**: beggining of **December**

# %%
profile_wind = pd.read_excel(data_path, sheet_name='profile_wind', 
                             names=list(week_numbers.keys()), header=None, index_col=0)

plt.figure(figsize=(12,6))
for week_num in profile_wind.columns.values:
    plt.plot(profile_wind[week_num], 'o--', label=f'week {week_num.split('_')[1]}')
plt.xlim(0,25)
plt.xticks(np.arange(0,25,2))
plt.title('Average Daily Onshore Wind Profiles', fontsize=15)
plt.xlabel('time [h]', fontsize=12)
plt.ylabel(r'Intensity compared to $P_{max}$', fontsize=12)
plt.legend()
plt.grid()
plt.savefig('figures/01_data_exploration/wind_profiles.pdf', bbox_inches='tight')
plt.show()

# %%
profile_PV = pd.read_excel(data_path, sheet_name='profile_PV', 
                           names=list(week_numbers.keys()), header=None, index_col=0)

plt.figure(figsize=(12,6))
for week_num in profile_PV.columns.values:
    plt.plot(profile_PV[week_num], 'o--', label=f'week {week_num}')
plt.xlim(0,25)
plt.xticks(np.arange(0,25,2))
plt.title('Average Daily PV Profiles', fontsize=15)
plt.xlabel('time [h]', fontsize=12)
plt.ylabel(r'Intensity compared to $P_{max}$', fontsize=12)
plt.legend()
plt.grid()
plt.savefig('figures/01_data_exploration/pv_profiles.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# missing value interpolation:
# ```python
# profile_PV['15'].interpolate(method='cubic')[profile_PV['15'].isna()].values[0]
# ```

# %% [markdown]
# # Electric Demand
#
# Electric demand [MWh] in Hungary across 4 weeeks (4*7 days) in hourly resolution.

# %%
demand = pd.DataFrame()
demand_df = pd.read_excel(data_path, sheet_name='demand').values.ravel() 
for i, week in enumerate(week_numbers.keys()):
	demand[week] = demand_df[i*len(demand_df)//4:(i+1)*len(demand_df)//4]

# %%
plt.figure(figsize=(12,6))
for week in demand.columns:
	plt.plot(demand[week], 'o-', ms=3, lw=1, label=week)
plt.title('Energy demand in hourly resolution', fontsize=15)
plt.xlabel('Time [h]', fontsize=12)
plt.ylabel('Demand [MWh]', fontsize=12)
plt.legend(bbox_to_anchor=(1, 1))
plt.xticks(np.arange(0, len(demand)+1, 24//4))
plt.xlim(0, len(demand))
plt.grid()
plt.savefig('figures/01_data_exploration/demand.pdf', bbox_inches='tight')
plt.show()
